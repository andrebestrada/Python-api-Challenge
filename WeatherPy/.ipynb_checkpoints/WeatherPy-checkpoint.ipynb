# %% [markdown]
# # WeatherPy
# ----
# ## Insights and conclusions
#
# 1. We can see a **strong negative correlation** between latitude and temperature, explaining only for northern hemisphere, the greater the latitude, the lesser temperature will be. In the other hand, we see a **positive correlation** for southern hemisphere were we can explain, the greater the latitude, the greater the temperature.
#
#
# 2. Referring to the other variables Humidity, Cloudiness and Wind Speed, **the data does not show any correlation** between these variables and the latitude of the city.
#
#
# 3. We can also infer that according to the Latitude vs Wind Speed scatter plot, we can see that the greatest outliers of windspeed belong to the northern hemisphere, but there is no correlation with the latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint
from scipy.stats import linregress
import scipy.stats as st

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
latitudes=[]
longitudes=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        latitudes.append(lat_lng[0])
        longitudes.append(lat_lng[1])
        
print(len(cities))
# cities=cities[:20]
# pd.DataFrame(lat_lngs)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_df=[]

index=1
counter=1
print('Beginning Data Retrieval     ')
print('-----------------------------')

for city in cities:

    url=f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
    response=requests.get(url).json()

    if index>50: 
        counter+=1
        index=0
        
    try:
        city_name=response["name"]
        index+=1
        
        city_df.append({'City':response["name"],
             'Lat':response['coord']['lat'],
             'Lng':response['coord']['lon'],
             'Max Temp':response['main']['temp_max'],
             'Humidity': response['main']['humidity'],
             'Cloudiness':response['clouds']['all'],
             'Wind Speed':response['wind']['speed'],
              'Country':response['sys']['country'],
              'Date':response['dt']})
        
        print(f'Processing Record {index} of Set {counter} | {city_name} ')
        
    except (KeyError, IndexError):
        print("City not found. Skipping...")
    
    
print('-----------------------------')
print('Data Retrieval Complete      ')
print('-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 2 of Set 1 | Mokhsogollokh
# Processing Record 3 of Set 1 | Busselton
# Processing Record 4 of Set 1 | San Policarpo
# Processing Record 5 of Set 1 | Ushuaia
# Processing Record 6 of Set 1 | Rikitea
# Processing Record 7 of Set 1 | Punta Arenas
# Processing Record 8 of Set 1 | Hermanus
# City not found. Skipping...
# Processing Record 9 of Set 1 | Lucapa
# Processing Record 10 of Set 1 | Saint-Philippe
# Processing Record 11 of Set 1 | Hobart
# Processing Record 12 of Set 1 | Atuona
# Processing Record 13 of Set 1 | Butaritari
# Processing Record 14 of Set 1 | Mount Gambier
# Processing Record 15 of Set 1 | Padang
# Processing Record 16 of Set 1 | Naryan-Mar
# Processing Record 17 of Set 1 | Jamestown
# Processing Record 18 of Set 1 | Upernavik
# Processing Record 19 of Set 1 | New Norfolk
# Processing Record 20 of Set 1 | Portland
# Processing Record 21 of Set 1 | Flin Flon
# Processing Record 22 of Set 1 | São José da Coroa Grande
# Processing Record 23 of Set 1 | Uthal
# Processing Record 24 of Set 1 | Point Pedro
# Processing Record 25 of Set 1 | Sept-Îles
# Processing Record 26 of Set 1 | Carroll
# Processing Record 27 of Set 1 | Oussouye
# City not found. Skipping...
# Processing Record 28 of Set 1 | Clyde River
# Processing Record 29 of Set 1 | Mataura
# Processing Record 30 of Set 1 | Bluff
# City not found. Skipping...
# Processing Record 31 of Set 1 | Hong Kong
# Processing Record 32 of Set 1 | Port Alfred
# Processing Record 33 of Set 1 | San Jose
# City not found. Skipping...
# Processing Record 34 of Set 1 | Broome
# Processing Record 35 of Set 1 | Bredasdorp
# Processing Record 21 of Set 4 | Arrondissement de Saint-Quentin
# Processing Record 22 of Set 4 | Severo-Kuril'sk
# Processing Record 23 of Set 4 | Sarai
# Processing Record 24 of Set 4 | Chokwé
# Processing Record 25 of Set 4 | Hebi
# Processing Record 26 of Set 4 | Batagay
# Processing Record 27 of Set 4 | Ilulissat
# Processing Record 28 of Set 4 | Dalby
# Processing Record 29 of Set 4 | Namatanai
# Processing Record 30 of Set 4 | Yaring
# Processing Record 31 of Set 4 | Grand-Santi
# Processing Record 32 of Set 4 | Nicolás R Casillas
# Processing Record 33 of Set 4 | Mwense
# Processing Record 34 of Set 4 | Tomatlán
# Processing Record 35 of Set 4 | Troitskiy
# Processing Record 36 of Set 4 | Udachny
# Processing Record 37 of Set 4 | Jiwani
# Processing Record 38 of Set 4 | Shimoda
# Processing Record 39 of Set 4 | Airai
# Processing Record 40 of Set 4 | Boa Vista
# Processing Record 41 of Set 4 | Oistins
# Processing Record 42 of Set 4 | Forsytheganj
# Processing Record 43 of Set 4 | Fort Nelson
# Processing Record 44 of Set 4 | Pisco
# Processing Record 45 of Set 4 | Bowmore
# Processing Record 46 of Set 4 | Nuevo Comalapa
# Processing Record 47 of Set 4 | Ermelo
# Processing Record 48 of Set 4 | Lebanon
# Processing Record 49 of Set 4 | Nizhniy Tsasuchey
# Processing Record 50 of Set 4 | Thabazimbi
# Processing Record 51 of Set 4 | Farafangana
# Processing Record 1 of Set 5 | Nizwá
# Processing Record 2 of Set 5 | Nanortalik
# City not found. Skipping...
# Processing Record 3 of Set 5 | Zeya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 5 | Port Hawkesbury
# Processing Record 5 of Set 5 | Lüderitz
# Processing Record 6 of Set 5 | Kavaratti
# Processing Record 7 of Set 5 | San Ramon
# Processing Record 8 of Set 5 | Hay River
# Processing Record 9 of Set 5 | Sobolevo
# Processing Record 10 of Set 5 | Paamiut
# Processing Record 11 of Set 5 | Mopti
# City not found. Skipping...
# Processing Record 12 of Set 5 | Lebu
# Processing Record 13 of Set 5 | Samoded
# Processing Record 14 of Set 5 | Ambulu
# Processing Record 15 of Set 5 | Zhigansk
# Processing Record 16 of Set 5 | Tonantins
# Processing Record 17 of Set 5 | Hambantota
# Processing Record 18 of Set 5 | Hofn
# Processing Record 19 of Set 5 | Vigrestad
# Processing Record 20 of Set 5 | Póvoa de Varzim
# Processing Record 21 of Set 5 | Rawson
# Processing Record 22 of Set 5 | Poum
# City not found. Skipping...
# Processing Record 23 of Set 5 | Omboué
# Processing Record 24 of Set 5 | Necochea
# Processing Record 25 of Set 5 | Cabo San Lucas
# City not found. Skipping...
# Processing Record 26 of Set 5 | Chambéry
# Processing Record 27 of Set 5 | Topeka
# City not found. Skipping...
# Processing Record 28 of Set 5 | Pevek
# Processing Record 29 of Set 5 | Bengkulu
# Processing Record 30 of Set 5 | Avera
# Processing Record 31 of Set 5 | Denpasar
# Processing Record 32 of Set 5 | Pooler
# Processing Record 33 of Set 5 | Comodoro Rivadavia
# Processing Record 34 of Set 5 | Gōtsuchō
# Processing Record 35 of Set 5 | Quatre Cocos
# Processing Record 36 of Set 5 | Tuktoyaktuk
# Processing Record 37 of Set 5 | Lobatse
# Processing Record 38 of Set 5 | Tautira
# Processing Record 39 of Set 5 | Talnakh
# Processing Record 40 of Set 5 | Casas Grandes
# City not found. Skipping...
# Processing Record 41 of Set 5 | Singapore
# Processing Record 42 of Set 5 | Vestmannaeyjar
# Processing Record 43 of Set 5 | Faya
# Processing Record 44 of Set 5 | Fukuechō
# Processing Record 45 of Set 5 | Tacuarembó
# Processing Record 46 of Set 5 | Codrington
# Processing Record 47 of Set 5 | Saskylakh
# Processing Record 48 of Set 5 | Visby
# Processing Record 49 of Set 5 | Kahului
# Processing Record 50 of Set 5 | Basco
# Processing Record 51 of Set 5 | Caravelas
# Processing Record 1 of Set 6 | Valparaíso
# Processing Record 2 of Set 6 | Jacareacanga
# Processing Record 3 of Set 6 | Baiyin
# Processing Record 4 of Set 6 | Médéa
# Processing Record 5 of Set 6 | Wau
# Processing Record 6 of Set 6 | Morón
# Processing Record 7 of Set 6 | Sokodé
# Processing Record 8 of Set 6 | Tura
# Processing Record 9 of Set 6 | Los Llanos de Aridane
# Processing Record 10 of Set 6 | Souillac
# Processing Record 11 of Set 6 | Geraldton
# Processing Record 12 of Set 6 | Charters Towers
# Processing Record 13 of Set 6 | Atar
# Processing Record 14 of Set 6 | Marquetalia
# Processing Record 15 of Set 6 | Nishihara
# Processing Record 16 of Set 6 | Chernushka
# Processing Record 17 of Set 6 | Saint Anthony
# Processing Record 18 of Set 6 | Baghdad
# Processing Record 19 of Set 6 | Muros
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 6 | Mitsamiouli
# Processing Record 21 of Set 6 | Chaohu
# Processing Record 22 of Set 6 | Ulaangom
# Processing Record 23 of Set 6 | Richards Bay
# Processing Record 24 of Set 6 | Chengzhong
# Processing Record 25 of Set 6 | Constitución
# Processing Record 26 of Set 6 | Te Anau
# Processing Record 27 of Set 6 | Cabra
# Processing Record 28 of Set 6 | Aksu
# Processing Record 29 of Set 6 | Dekar
# Processing Record 30 of Set 6 | Ocampo
# Processing Record 31 of Set 6 | Anadyr
# Processing Record 32 of Set 6 | Sidi Ali
# Processing Record 33 of Set 6 | Rocha
# Processing Record 34 of Set 6 | Laas
# Processing Record 35 of Set 6 | Bariloche
# Processing Record 36 of Set 6 | Alekseyevsk
# Processing Record 37 of Set 6 | La Ronge
# Processing Record 38 of Set 6 | Karratha
# Processing Record 39 of Set 6 | Cayenne
# Processing Record 40 of Set 6 | Bismil
# Processing Record 41 of Set 6 | Kumul
# Processing Record 42 of Set 6 | Okato
# Processing Record 43 of Set 6 | Sinnamary
# Processing Record 44 of Set 6 | São João da Barra
# Processing Record 45 of Set 6 | Ushtobe
# Processing Record 46 of Set 6 | Deputatsky
# Processing Record 47 of Set 6 | Cortez
# Processing Record 48 of Set 6 | Andros Town
# Processing Record 49 of Set 6 | Saint-Pierre
# City not found. Skipping...
# Processing Record 50 of Set 6 | Turukhansk
# Processing Record 51 of Set 6 | Sokoni
# Processing Record 1 of Set 7 | Chimoio
# Processing Record 2 of Set 7 | Severodvinsk
# Processing Record 3 of Set 7 | Mwinilunga
# Processing Record 4 of Set 7 | Nome
# Processing Record 5 of Set 7 | Havelock
# Processing Record 6 of Set 7 | Kaeo
# Processing Record 43 of Set 9 | Kaitangata
# Processing Record 44 of Set 9 | Zilair
# City not found. Skipping...
# Processing Record 45 of Set 9 | Katsuura
# Processing Record 46 of Set 9 | Clarence Town
# Processing Record 47 of Set 9 | Basoko
# Processing Record 48 of Set 9 | Manavālakurichi
# Processing Record 49 of Set 9 | Cap Malheureux
# Processing Record 50 of Set 9 | Potsdam
# Processing Record 51 of Set 9 | Sakakah
# Processing Record 1 of Set 10 | Guarenas
# Processing Record 2 of Set 10 | Tambacounda
# Processing Record 3 of Set 10 | Santander
# Processing Record 4 of Set 10 | Sioux Lookout
# Processing Record 5 of Set 10 | Muskogee
# Processing Record 6 of Set 10 | Muskegon
# Processing Record 7 of Set 10 | Ouésso
# Processing Record 8 of Set 10 | Tilichiki
# Processing Record 9 of Set 10 | Stephenville
# Processing Record 10 of Set 10 | Tabuk
# Processing Record 11 of Set 10 | Kathmandu
# Processing Record 12 of Set 10 | Iracoubo
# Processing Record 13 of Set 10 | Revelstoke
# Processing Record 14 of Set 10 | Malakal
# Processing Record 15 of Set 10 | Mahibadhoo
# Processing Record 16 of Set 10 | Webuye
# Processing Record 17 of Set 10 | Gondanglegi
# Processing Record 18 of Set 10 | Blackwater
# Processing Record 19 of Set 10 | Jintūr
# Processing Record 20 of Set 10 | Oga
# City not found. Skipping...
# Processing Record 21 of Set 10 | Alvarães
# Processing Record 22 of Set 10 | Boende
# Processing Record 23 of Set 10 | Stabat
# Processing Record 24 of Set 10 | Varhaug
# Processing Record 25 of Set 10 | Pontianak
# Processing Record 26 of Set 10 | Kushiro
# Processing Record 27 of Set 10 | Derzhavīnsk
# Processing Record 28 of Set 10 | Smirnykh
# Processing Record 29 of Set 10 | Xining
# Processing Record 30 of Set 10 | Río Gallegos
# City not found. Skipping...
# Processing Record 31 of Set 10 | Nouakchott
# Processing Record 32 of Set 10 | Mumford
# Processing Record 33 of Set 10 | Solnechnyy
# City not found. Skipping...
# Processing Record 34 of Set 10 | Sabaudia
# Processing Record 35 of Set 10 | Kerman
# Processing Record 36 of Set 10 | Winona
# Processing Record 37 of Set 10 | Morayfield
# City not found. Skipping...
# Processing Record 38 of Set 10 | Peniche
# Processing Record 39 of Set 10 | Dawson Creek
# Processing Record 40 of Set 10 | Bayan
# Processing Record 41 of Set 10 | Taywarah
# Processing Record 42 of Set 10 | Reshetylivka
# Processing Record 43 of Set 10 | Porto-Novo
# Processing Record 44 of Set 10 | San Juan
# Processing Record 45 of Set 10 | Aklavik
# Processing Record 46 of Set 10 | Pokhara
# Processing Record 47 of Set 10 | Lakhdenpokh'ya
# Processing Record 48 of Set 10 | Masunga
# Processing Record 49 of Set 10 | Khandagayty
# Processing Record 50 of Set 10 | Gold Coast
# Processing Record 51 of Set 10 | Katangli
# City not found. Skipping...
# Processing Record 1 of Set 11 | Verkhnevilyuysk
# Processing Record 2 of Set 11 | Tessalit
# Processing Record 3 of Set 11 | Goderich
# Processing Record 4 of Set 11 | Manokwari
# Processing Record 5 of Set 11 | Sleaford
# Processing Record 6 of Set 11 | Funadhoo
# Processing Record 7 of Set 11 | Zarubino
# Processing Record 8 of Set 11 | Abu Dhabi
# City not found. Skipping...
# Processing Record 9 of Set 11 | Bud
# Processing Record 10 of Set 11 | Cockburn Town
# Processing Record 11 of Set 11 | Front Royal
# Processing Record 12 of Set 11 | Mainit
# Processing Record 13 of Set 11 | Bone
# Processing Record 14 of Set 11 | San Quintín
# Processing Record 15 of Set 11 | Carutapera
# Processing Record 16 of Set 11 | Port Macquarie
# Processing Record 17 of Set 11 | Strugari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 11 | Nuuk
# Processing Record 19 of Set 11 | Coyhaique
# Processing Record 20 of Set 11 | Attur
# Processing Record 21 of Set 11 | Daokou
# Processing Record 22 of Set 11 | Nūzvīd
# Processing Record 23 of Set 11 | Mandalgovi
# Processing Record 24 of Set 11 | Corner Brook
# Processing Record 25 of Set 11 | Itoman
# City not found. Skipping...
# Processing Record 26 of Set 11 | Port Hedland
# Processing Record 27 of Set 11 | Copiapó
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 11 | Maumere
# Processing Record 29 of Set 11 | Vardø
# Processing Record 30 of Set 11 | Plettenberg Bay
# City not found. Skipping...
# Processing Record 31 of Set 11 | Vitim
# Processing Record 32 of Set 11 | Jämsä
# Processing Record 33 of Set 11 | Nsoko
# Processing Record 34 of Set 11 | Ismailia
# Processing Record 35 of Set 11 | Vila Franca do Campo
# Processing Record 36 of Set 11 | Patrocínio
# Processing Record 37 of Set 11 | Onega
# City not found. Skipping...
# Processing Record 38 of Set 11 | Paddhari
# Processing Record 39 of Set 11 | Sultepec
# Processing Record 40 of Set 11 | Nikel
# Processing Record 41 of Set 11 | Dhārchula
# Processing Record 42 of Set 11 | Sterling
# Processing Record 43 of Set 11 | Vandœuvre-lès-Nancy
# Processing Record 44 of Set 11 | Broken Hill
# Processing Record 45 of Set 11 | Maragogi
# Processing Record 46 of Set 11 | San Luis
# Processing Record 47 of Set 11 | Nara
# Processing Record 48 of Set 11 | Camopi
# Processing Record 49 of Set 11 | Aleksandro-Nevskiy
# Processing Record 50 of Set 11 | Najrān
# Processing Record 51 of Set 11 | Örebro
# Processing Record 1 of Set 12 | Kidal
# Processing Record 2 of Set 12 | Aksarka
# Processing Record 3 of Set 12 | Lorengau
# Processing Record 4 of Set 12 | Mehnagar
# Processing Record 5 of Set 12 | São Gabriel da Cachoeira
# Processing Record 6 of Set 12 | Perth
# Processing Record 7 of Set 12 | Vilhena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df=pd.DataFrame(city_df)

city_df.to_csv('../Resources/City Data.csv')
city_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mokhsogollokh  61.4681  128.9203     28.94        97         100
# 1      Busselton -33.6500  115.3333     48.99        98          72
# 2  San Policarpo  12.1791  125.5072     76.48        84          73
# 3        Ushuaia -54.8000  -68.3000     42.80        56          20
# 4        Rikitea -23.1203 -134.9692     76.37        68          99
#
#    Wind Speed Country        Date
# 0        3.53      RU  1619732188
# 1        9.10      AU  1619732189
# 2        2.48      PH  1619732189
# 3        3.44      AR  1619731981
# 4        8.75      PF  1619732190

# %%
city_df.describe().round(2)
# Out:
#           Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# count  567.00  567.00    567.00    567.00      567.00      567.00
# mean    20.29   22.81     61.00     71.60       54.10        7.49
# std     33.65   89.82     19.02     22.01       37.99        5.09
# min    -54.80 -179.17     -1.93      7.00        0.00        0.31
# 25%     -6.14  -56.86     46.40     61.00       18.00        3.51
# 50%     24.69   27.85     63.82     77.00       65.00        6.31
# 75%     48.83  103.95     77.00     88.00       90.00       10.29
# max     78.22  177.48    100.99    100.00      100.00       29.93
#
#                Date
# count  5.670000e+02
# mean   1.619732e+09
# std    9.366000e+01
# min    1.619732e+09
# 25%    1.619732e+09
# 50%    1.619732e+09
# 75%    1.619732e+09
# max    1.619732e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
over_humidity = city_df[city_df['Humidity']>100].index
over_humidity
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data=city_df.drop(over_humidity , inplace=False)
clean_city_data.head().round(2)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Mokhsogollokh  61.47  128.92     28.94        97         100        3.53
# 1      Busselton -33.65  115.33     48.99        98          72        9.10
# 2  San Policarpo  12.18  125.51     76.48        84          73        2.48
# 3        Ushuaia -54.80  -68.30     42.80        56          20        3.44
# 4        Rikitea -23.12 -134.97     76.37        68          99        8.75
#
#   Country        Date
# 0      RU  1619732188
# 1      AU  1619732189
# 2      PH  1619732189
# 3      AR  1619731981
# 4      PF  1619732190

# %%
clean_city_data[['Lat','Max Temp']] = np.int64(clean_city_data[['Lat','Max Temp']])
# clean_city_data.dtypes

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data.plot.scatter(x="Lat", y="Max Temp", s=40,color= '#4285F4' , edgecolors = "black")

# Format and labels
plt.title("City Latitude vs. Max Temperature (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True, which="major",axis="both",linestyle="-")  
plt.savefig("Graphs/LatVsTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_data.plot.scatter(x="Lat", y="Humidity", s=40,color= '#4285F4' , edgecolors = "black")

# Format and labels
plt.title("City Latitude vs. Humidity (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid (b=True, which="major",axis="both",linestyle="-")  
plt.savefig("Graphs/LatVsHum.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_data.plot.scatter(x="Lat", y="Cloudiness", s=40,color= '#4285F4' , edgecolors = "black")

# Format and labels
plt.title("City Latitude vs. Cloudiness (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True, which="major",axis="both",linestyle="-")  
plt.savefig("Graphs/LatVsCloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_data.plot.scatter(x="Lat", y="Wind Speed", s=40,color= '#4285F4' , edgecolors = "black")

# Format and labels
plt.title("City Latitude vs. Wind Speed (04/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid (b=True, which="major",axis="both",linestyle="-")  
plt.savefig("Graphs/LatVsWind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hemisphere = clean_city_data.loc[clean_city_data["Lat"] > 0]
southern_hemisphere = clean_city_data.loc[clean_city_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = northern_hemisphere["Lat"]
y_axis = northern_hemisphere["Max Temp"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(10,20),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Max Temp (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()

plt.savefig("Graphs/CorrelationNorth(LatVsTemp).png")
# Out:
# The correlation coefficient is -0.88
# The r-value is: 0.7723119259772745

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = southern_hemisphere["Lat"]
y_axis = southern_hemisphere["Max Temp"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,80),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Max Temp (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()

plt.savefig("Graphs/CorrelationSouth(LatVsTemp).png")
# Out:
# The correlation coefficient is 0.78
# The r-value is: 0.6014951233438482

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = northern_hemisphere["Lat"]
y_axis = northern_hemisphere["Humidity"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Humidity (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

plt.savefig("Graphs/CorrelationNorth(LatVsHumidity).png")
# Out:
# The correlation coefficient is 0.13
# The r-value is: 0.01632314698791107

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = southern_hemisphere["Lat"]
y_axis = southern_hemisphere["Humidity"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Humidity (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

plt.savefig("Graphs/CorrelationSouth(LatVsHumidity).png")
# Out:
# The correlation coefficient is 0.17
# The r-value is: 0.02822203388587102

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = northern_hemisphere["Lat"]
y_axis = northern_hemisphere["Cloudiness"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(40,30),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Cloudiness (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

plt.savefig("Graphs/CorrelationNorth(LatVsCloud).png")
# Out:
# The correlation coefficient is 0.15
# The r-value is: 0.02187840314880427

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = southern_hemisphere["Lat"]
y_axis = southern_hemisphere["Cloudiness"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Cloudiness (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

plt.savefig("Graphs/CorrelationSouth(LatVsCloud).png")
# Out:
# The correlation coefficient is 0.14
# The r-value is: 0.019718369441471307

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = northern_hemisphere["Lat"]
y_axis = northern_hemisphere["Wind Speed"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(40,15),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Wind Speed (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

plt.savefig("Graphs/CorrelationNorth(LatVsWind).png")
# Out:
# The correlation coefficient is 0.12
# The r-value is: 0.015325333432538515

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Linear regression model and correlation coefficient 

x_axis = southern_hemisphere["Lat"]
y_axis = southern_hemisphere["Wind Speed"]

corr=round(st.pearsonr(x_axis,y_axis)[0],2)

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

print(f"The correlation coefficient is {corr}")
print(f"The r-value is: {rvalue**2}")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_axis,y_axis)
plt.plot(x_axis,regress_values,"r-")
plt.annotate(line_eq,(-50,6),fontsize=15,color="red")
plt.title("Correlation City Latitude vs Wind Speed (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

plt.savefig("Graphs/CorrelationSouth(LatVsWind).png")
# Out:
# The correlation coefficient is -0.21
# The r-value is: 0.044424321762544995

# %%
clean_city_data.to_csv('../Resources/Clean City Data.csv')

# %%
clean_city_data
# Out:
#                          City  Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Mokhsogollokh   61  128.9203        28        97         100
# 1                   Busselton  -33  115.3333        48        98          72
# 2               San Policarpo   12  125.5072        76        84          73
# 3                     Ushuaia  -54  -68.3000        42        56          20
# 4                     Rikitea  -23 -134.9692        76        68          99
# ..                        ...  ...       ...       ...       ...         ...
# 562                  Lorengau   -2  147.2712        82        75          44
# 563                  Mehnagar   25   83.1167        85        21           0
# 564  São Gabriel da Cachoeira    0  -67.0892        72        98         100
# 565                     Perth  -31  115.8333        61        93          20
# 566                   Vilhena  -12  -60.1458        75        78          20
#
#      Wind Speed Country        Date
# 0          3.53      RU  1619732188
# 1          9.10      AU  1619732189
# 2          2.48      PH  1619732189
# 3          3.44      AR  1619731981
# 4          8.75      PF  1619732190
# ..          ...     ...         ...
# 562        3.96      PG  1619732434
# 563        6.55      IN  1619732434
# 564        1.30      BR  1619732435
# 565        5.75      AU  1619732148
# 566       10.36      BR  1619732435
#
# [567 rows x 9 columns]
